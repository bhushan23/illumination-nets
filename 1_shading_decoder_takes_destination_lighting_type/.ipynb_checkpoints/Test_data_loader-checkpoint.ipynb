# %%
import torch
import sys
sys.path.insert(0, './core')
sys.path.insert(0, './models')
import DAELightTransferDataLoader as lightDL
import torchvision.utils as tutils
import matplotlib.pyplot as plt
from PIL import Image
from torchvision import transforms
data_root = './multipie_select_batches'

# %%
training_data = []
training_data.append(data_root + '/session01_01_select')
training_data.append(data_root + '/session01_02_select')
training_data.append(data_root + '/session01_03_select')
training_data.append(data_root + '/session01_04_select')
training_data.append(data_root + '/session01_05_select')
training_data.append(data_root + '/session01_06_select')
training_data.append(data_root + '/session01_07_select')

transform = transforms.Compose([
            #transforms.Resize(),
            transforms.ToTensor(),
            transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))
    ])

data_set = lightDL.FareMultipieLightingTripletsFrontal(None, root=training_data, transform = None, resize=64)

print(len(data_set))

data_loader = torch.utils.data.DataLoader(data_set, batch_size = 64, shuffle = True)
# Out:
# ['./multipie_select_batches/session01_01_select', './multipie_select_batches/session01_02_select', './multipie_select_batches/session01_03_select', './multipie_select_batches/session01_04_select', './multipie_select_batches/session01_05_select', './multipie_select_batches/session01_06_select', './multipie_select_batches/session01_07_select']
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-4-1567c6934aa0> in <module>()
#      14     ])
#      15
# ---> 16 data_set = lightDL.FareMultipieLightingTripletsFrontal(None, root=training_data, transform = None, resize=64)
#      17
#      18 print(len(data_set))
#
# ~/work/thesis/Sem2/source/experiment/illumination-nets/1_lighting_transfer_with_unknown_light_source/core/DAELightTransferDataLoader.py in __init__(self, opt, root, resize, transform, return_paths)
#      35         transform=None, return_paths=False):
#      36         self.opt = opt
# ---> 37         sess_img_map = self.make_dataset_same_face_diff_light_multipie(root)
#      38         if len(sess_img_map) == 0:
#      39             raise(RuntimeError("Found 0 images in: " + root + "\n"
#
# ~/work/thesis/Sem2/source/experiment/illumination-nets/1_lighting_transfer_with_unknown_light_source/core/DAELightTransferDataLoader.py in make_dataset_same_face_diff_light_multipie(self, dirpath_root_list)
#     123         # assert os.path.isdir(dirpath_root)
#     124         for dirpath_root in dirpath_root_list:
# --> 125             assert os.path.isdir(dirpath_root)
#     126             # img_map  = {} # maps ids to list of index in idl_list
#     127             # hack for finding session name
#
# AssertionError:

# %%
data = iter(data_loader)
s1, img1, s2, img2 = next(data)
print(img1.shape)
# Out:
# torch.Size([64, 3, 64, 64])

# %%
grid = tutils.make_grid(img1, nrow=8, padding=2)
#ndarr = grid.mul(255).clamp(0, 255).byte().permute(1, 2, 0).cpu().numpy()
ndarr = grid.permute(1, 2, 0).cpu().numpy()
im = Image.fromarray(ndarr)
plt.imshow(im)
plt.show()

# %%
grid = tutils.make_grid(img2, nrow=8, padding=2)
#ndarr = grid.mul(255).clamp(0, 255).byte().permute(1, 2, 0).cpu().numpy()
ndarr = grid.permute(1, 2, 0).cpu().numpy()
im = Image.fromarray(ndarr)
plt.imshow(im)
plt.show()
